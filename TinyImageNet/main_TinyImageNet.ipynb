# %%
# !nvidia-smi
# Out:
# Sun Sep 18 13:32:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
! unzip "/content/tiny-imagenet-200.zip"
# !rm -r /content/tiny-imagenet-200/test
# !python3 /content/gdrive/MyDrive/EXP/AdaNorm/TinyImageNet/val_format.py
# !python /content/gdrive/MyDrive/EXP/AdaNorm/TinyImageNet/resize.py
# !rm -r /content/tiny-imagenet-200/*/*/images
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/tiny-imagenet-200/val/n03447447/val_3619.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_7054.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_4519.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_9800.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_3833.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_519.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_396.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_5059.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_9227.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_6213.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_7409.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_4200.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_1407.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_480.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_6515.JPEG
# /content/tiny-imagenet-200/val/n03447447/val_4661.JPEG
# ...

# %%
cd '/content/gdrive/My Drive/EXP/AdaInject/TinyImageNet/'
# Out:
# /content/gdrive/My Drive/EXP/AdaInject/TinyImageNet

# %%
# !python main_TinyImageNet.py
#!python main_TinyImageNet.py --resume --lr=0.001
#!python main_TinyImageNet.py --resume --lr=0.0001
# Out:
# ==> Preparing data..
# ==> Building model..
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
#
# Epoch: 0
# /content/gdrive/My Drive/EXP/AdaInject/TinyImageNet/AdamInject.py:71: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   exp_avg.mul_(beta1).add_(1 - beta1, dg)
# ...
